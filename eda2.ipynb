# %% [markdown]
# **<span style="font-size:18px; color: LightBlue;">Reading all files and display heads for initial analysis</span>**

# %%
import pandas as pd

# %%
df = pd.read_csv("../paediatric-intensive-care-database-1.1.0/SURGERY_VITAL_SIGNS.csv")

df.shape
# Out:
# (1216011, 9)

# %%
df = pd.read_csv("../paediatric-intensive-care-database-1.1.0/csv gz files/SURGERY_VITAL_SIGNS.csv")

df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  VISIT_ID  OPER_ID  ITEM_NO  \
# 0       1        4531   104527         1        1        9
# 1       2        4531   104527         1        1       10
# 2       3        4531   104527         1        1       12
# 3       4        4531   104527         1        1       13
# 4       5        4322   104884         2        4       15
#
#            MONITORTIME ITEMID  VALUE
# 0  2073-09-01 14:50:00    SV1    148
# 1  2073-09-01 14:55:00    SV1    145
# 2  2073-09-01 15:05:00    SV1    150
# 3  2073-09-01 15:05:00    SV1    147
# 4  2097-07-24 15:30:00    SV1    119

# %%
df1 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/ADMISSIONS.csv")
df1.shape
df1.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0       1          26   100000  2098-11-09 18:30:55  2098-11-14 09:18:00
# 1       2          28   100001  2104-09-03 10:36:47  2104-09-12 14:51:00
# 2       3          29   100002  2062-11-29 20:52:52  2062-12-07 14:27:00
# 3       4          30   100003  2098-11-21 15:38:47  2098-11-26 01:33:00
# 4       5          31   100004  2071-11-13 19:43:13  2071-11-15 13:40:00
#
#              DEATHTIME ADMISSION_DEPARTMENT DISCHARGE_DEPARTMENT INSURANCE  \
# 0                  NaN          General ICU          General ICU  Self Pay
# 1  2104-09-12 14:51:00          General ICU          General ICU  Self Pay
# 2                  NaN          General ICU          General ICU  Self Pay
# 3  2098-11-26 01:33:00          General ICU          General ICU  Discount
# 4  2071-11-15 13:40:00          General ICU          General ICU  Self Pay
#
# ...

# %%
df2 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/CHARTEVENTS.csv")
df2.shape
df2.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID            CHARTTIME  \
# 0       1       11062   111384         NaN    1008  2077-05-12 06:48:00
# 1       2        9349   109531    210016.0    1003  2079-01-06 13:53:30
# 2       3       11062   111384    211848.0    1004  2077-05-25 21:59:51
# 3       4       12441   112881    213285.0    1031  2107-08-18 06:36:47
# 4       5        9349   109531    210016.0    1001  2079-01-06 13:53:30
#
#              STORETIME  VALUE  VALUENUM VALUEUOM
# 0  2077-05-12 06:48:00  596.0     596.0       ml
# 1  2079-01-06 13:53:30  110.0     110.0      bpm
# 2  2077-05-25 21:59:51   31.0      31.0      bpm
# 3  2107-08-18 06:36:47   30.0      30.0       °C
# 4  2079-01-06 13:53:30   37.4      37.4       °C

# %%
df3 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/D_ICD_DIAGNOSES.csv")
df3.shape
df3.head()
# Out:
#    ROW_ID ICD10_CODE_CN ICD10_CODE TITLE_CN  \
# 0       1       A00.000      A00.0  古典生物型霍乱
# 1       2       A00.100      A00.1   埃尔托型霍乱
# 2       3       A00.900      A00.9       霍乱
# 3       4       A01.000      A01.0       伤寒
# 4       5       A01.001      A01.0       伤寒
#
#                                                TITLE
# 0  Cholera due to Vibrio cholerae 01, biovar chol...
# 1    Cholera due to Vibrio cholerae 01, biovar eltor
# 2                               Cholera, unspecified
# 3                                      Typhoid fever
# 4                                      Typhoid fever

# %%
df15 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/DIAGNOSES_ICD.csv")
df15.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD10_CODE_CN
# 0       1       12575   113742        1       Q43.901
# 1       2         614   100603        1       G04.916
# 2       3        1888   101880        1       Q40.001
# 3       4        8792   108934        1       S02.902
# 4       5       10368   111492        1       J18.900

# %%
df4 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/D_ITEMS.csv")
df4.shape
df4.head()
# Out:
#    ROW_ID ITEMID LABEL_CN              LABEL      LINKSTO  \
# 0       1   1001       体温        Temperature  chartevents
# 1       2   1002       脉搏              Pulse  chartevents
# 2       3   1003       心率         Heart Rate  chartevents
# 3       4   1004       呼吸   Respiratory Rate  chartevents
# 4       5   1006    血氧饱和度  Oxygen saturation  chartevents
#
#               CATEGORY  UNITNAME
# 0  Routine Vital Signs        °C
# 1                  NaN       bpm
# 2  Routine Vital Signs       bpm
# 3  Routine Vital Signs  insp/min
# 4  Routine Vital Signs         %

# %%
df5 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/D_LABITEMS.csv")
df5.shape
df5.head()
# Out:
#    ROW_ID  ITEMID   LABEL_CN                 LABEL  FLUID    CATEGORY  \
# 0       1    5002     嗜酸性粒细胞           Eosinophils  Blood  Hematology
# 1       2    5005  中性粒细胞%(*)         Neutrophils %  Blood  Hematology
# 2       3    5006   淋巴细胞%(*)  Lymphocytes, Percent  Blood  Hematology
# 3       4    5008   巨噬细胞%(*)           Macrophage%  Blood   Chemistry
# 4       5    5010   其它细胞%(*)         Other cells %    NaN         NaN
#
#   LOINC_CODE
# 0      711-2
# 1        NaN
# 2    26478-8
# 3        NaN
# 4        NaN

# %%
df6 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/EMR_SYMPTOMS.csv")
df6.shape
df6.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID   EMR_ID           RECORDTIME SYMPTOM_NAME_CN  \
# 0       1       12104   112523  3930272  2100-07-02 13:04:24              咳嗽
# 1       2       12104   112523  3930272  2100-07-02 13:04:24             胃纳可
# 2       3       12104   112523  3930272  2100-07-02 13:04:24              神清
# 3       4       12104   112523  3930272  2100-07-02 13:04:24             精神软
# 4       5       12104   112523  3930272  2100-07-02 13:04:24             心律齐
#
#            SYMPTOM_NAME SYMPTOM_ATTRIBUTE
# 0                 cough                 +
# 1         good appetite                 +
# 2           good spirit                 +
# 3              listless                 +
# 4  regular heart rhythm                 +

# %%
df7 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/ICUSTAYS.csv")
df7.shape
df7.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID FIRST_CAREUNIT LAST_CAREUNIT  \
# 0       1          26   100000      200532    General ICU   General ICU
# 1       2          28   100001      200533    General ICU   General ICU
# 2       3          29   100002      200534    General ICU   General ICU
# 3       4          30   100003      200535    General ICU   General ICU
# 4       5          31   100004      200536    General ICU   General ICU
#
#    FIRST_WARDID  LAST_WARDID               INTIME              OUTTIME     LOS
# 0           340          340  2098-11-09 18:30:55  2098-11-14 09:18:00  4.6167
# 1           340          340  2104-09-03 10:36:46  2104-09-12 14:51:00  9.1771
# 2           340          340  2062-11-29 20:52:52  2062-12-07 14:27:00  7.7326
# 3           340          340  2098-11-21 15:38:47  2098-11-26 01:33:00  4.4132
# 4           340          340  2071-11-13 19:43:12  2071-11-15 13:40:00  1.7479

# %%
df8 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/INPUTEVENTS.csv")
df8.shape
df8.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            CHARTTIME  AMOUNT  \
# 0       1        2946   103020    203485.0  2092-01-06 07:07:55   355.0
# 1       2        2993   103065    203530.0  2098-04-06 06:11:48   336.0
# 2       3        2981   103053    203518.0  2102-01-15 06:12:06    72.0
# 3       4        2989   103061    203526.0  2097-02-14 06:52:28  1382.0
# 4       5        2894   102970    203435.0  2085-05-12 06:12:16   480.0
#
#   AMOUNTUOM            STORETIME
# 0        ml  2092-01-06 07:07:55
# 1        ml  2098-04-06 06:11:48
# 2        ml  2102-01-15 06:12:06
# 3        ml  2097-02-14 06:52:28
# 4        ml  2085-05-12 06:12:16

# %%
df9 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/LABEVENTS.csv")
df9.shape
df9.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ITEMID            CHARTTIME VALUE  VALUENUM  \
# 0       1        3665   103732    5244  2077-10-25 09:23:38  27.2     27.20
# 1       2        3665   103732    5247  2077-10-25 09:23:38  0.86      0.86
# 2       3        3665   103732    5248  2077-10-25 09:23:38  22.2     22.20
# 3       4        3665   103732    5249  2077-10-25 09:23:38  -0.3     -0.30
# 4       5        3665   103732    5250  2077-10-25 09:23:38  61.4     61.40
#
#   VALUEUOM FLAG
# 0     mmHg    l
# 1      NaN    z
# 2   mmol/L    z
# 3   mmol/L    z
# 4        %    h

# %%
df10 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/MICROBIOLOGYEVENTS.csv")
df10.shape
df10.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            CHARTTIME  \
# 0       1        4981   104977  2066-10-09 11:29:00
# 1       2        4981   104977  2066-10-09 11:29:00
# 2       3        4981   104977  2066-10-09 11:29:00
# 3       4        4981   104977  2066-10-09 11:29:00
# 4       5        4981   104977  2066-10-09 11:29:00
#
#                  SPEC_ITEMID                                   SPEC_TYPE_DESC  \
# 0  LIS031294+LIS0204+LIS0320  血培养含真菌(阳性加药敏),常规药敏定量试验(MIC),耐甲氧西林葡萄球菌检测MRS.AMRS
# 1  LIS031294+LIS0204+LIS0320  血培养含真菌(阳性加药敏),常规药敏定量试验(MIC),耐甲氧西林葡萄球菌检测MRS.AMRS
# 2  LIS031294+LIS0204+LIS0320  血培养含真菌(阳性加药敏),常规药敏定量试验(MIC),耐甲氧西林葡萄球菌检测MRS.AMRS
# 3  LIS031294+LIS0204+LIS0320  血培养含真菌(阳性加药敏),常规药敏定量试验(MIC),耐甲氧西林葡萄球菌检测MRS.AMRS
# 4  LIS031294+LIS0204+LIS0320  血培养含真菌(阳性加药敏),常规药敏定量试验(MIC),耐甲氧西林葡萄球菌检测MRS.AMRS
#
#   ORG_ITEMID     ORG_NAME AB_ITEMID    AB_NAME DILUTION_TEXT  \
# 0     MIC310        人葡萄球菌    MIC473       莫西沙星           >=8
# ...

# %%
df11 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/OR_EXAM_REPORTS.csv")
df11.shape
df11.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID             EXAMTIME           REPORTTIME  \
# 0       1        1491   101788  2075-04-08 07:44:45  2075-04-08 07:45:08
# 1       2        7525   107581  2091-09-08 10:25:15  2091-09-08 14:37:55
# 2       3        8811   108952  2115-11-13 10:57:33  2115-11-13 10:56:41
# 3       4        8423   108545  2106-12-17 19:50:59  2106-12-17 22:11:52
# 4       5        8232   108356                  NaN  2114-09-27 15:39:25
#
#   EXAM_ITEM_TYPE_NAME                  EXAM_ITEM_NAME EXAM_PART_NAME
# 0                  CR                              DR          Chest
# 1                  CR                          X-rays          Chest
# 2                  CR                          X-rays          Chest
# 3                  CR                          X-rays          Chest
# 4                  GM  Routine Pathologic Examination            NaN

# %%
df12 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/OUTPUTEVENTS.csv")
df12.shape
df12.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            CHARTTIME  ITEMID  \
# 0       1        8800   108941         NaN  2080-11-15 21:11:00    1034
# 1       2        8800   108941         NaN  2080-11-17 18:00:00    1034
# 2       3        8800   108941         NaN  2080-11-22 02:44:00    1034
# 3       4        8800   108941         NaN  2080-11-21 15:05:00    1034
# 4       5        8800   108941         NaN  2080-11-21 06:11:00    1034
#
#    VALUE VALUEUOM            STORETIME
# 0   39.0       ml  2080-11-15 21:11:00
# 1    6.0       ml  2080-11-17 18:00:00
# 2   30.0       ml  2080-11-22 02:44:00
# 3   36.0       ml  2080-11-21 15:05:00
# 4   10.0       ml  2080-11-21 06:11:00

# %%
df13 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/PATIENTS.csv")
df13.shape
df13.head()
# Out:
#    ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0       1           2      M  2068-11-30 00:00:00  2081-09-28 10:06:00
# 1       2           9      M  2104-03-09 00:00:00                  NaN
# 2       3          56      F  2110-01-08 13:40:00                  NaN
# 3       4          79      F  2094-08-25 00:00:00                  NaN
# 4       5          96      M  2050-12-17 00:00:00                  NaN
#
#    EXPIRE_FLAG
# 0            1
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df14 = pd.read_csv("../paediatric-intensive-care-database-1.1.0/PRESCRIPTIONS.csv")
df14.shape
df14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1256591 entries, 0 to 1256590
# Data columns (total 13 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   ROW_ID             1256591 non-null  int64
#  1   SUBJECT_ID         1256591 non-null  int64
#  2   HADM_ID            1256591 non-null  int64
#  3   ICUSTAY_ID         857884 non-null   float64
#  4   STARTDATE          1256589 non-null  object
#  5   ENDDATE            275511 non-null   object
#  6   DRUG_NAME          1256591 non-null  object
#  7   DRUG_NAME_EN       1256591 non-null  object
#  8   PROD_STRENGTH      1233998 non-null  object
#  9   DRUG_NAME_GENERIC  76888 non-null    object
#  10  DOSE_VAL_RX        1256591 non-null  float64
#  11  DOSE_UNIT_RX       1245243 non-null  object
#  12  DRUG_FORM          1256588 non-null  object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 124.6+ MB
